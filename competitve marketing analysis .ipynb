# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sentiment = pd.read_csv(r'C:\Users\chewi\OneDrive\Desktop\Competitive Marketing Analysis\Data\Sentiment.csv')
product = pd.read_csv(r'C:\Users\chewi\OneDrive\Desktop\Competitive Marketing Analysis\Data\Product.csv')
geo = pd.read_csv(r'C:\Users\chewi\OneDrive\Desktop\Competitive Marketing Analysis\Data\Geo.csv')
date = pd.read_csv(r'C:\Users\chewi\OneDrive\Desktop\Competitive Marketing Analysis\Data\Date.csv')
salesfact = pd.read_csv(r'C:\Users\chewi\OneDrive\Desktop\Competitive Marketing Analysis\Data\SalesFact.csv')

# %%
print(sentiment)
# Out:
#        DateID  StateID  ManufacturerID  Score Manufacturer  \
# 0           7       14              13     89       Salvus
# 1           7       27              13     86       Salvus
# 2           7       44              13     85       Salvus
# 3           7       42              13     73       Salvus
# 4           7       41              13     82       Salvus
# ...       ...      ...             ...    ...          ...
# 21468      19        1              11     70        Pomum
# 21469      19       33              11     84        Pomum
# 21470      19       34              11     70        Pomum
# 21471      19       25              11     63        Pomum
# 21472      19       25              11     86        Pomum
#
#                           Date State    zip  ProductID
# 0      2013-07-01 00:00:00.000    IL  62356       1688
# 1      2013-07-01 00:00:00.000    ND  58001       1688
# 2      2013-07-01 00:00:00.000    VA  20041       1688
# ...

# %%
sentiment.head(10)
# Out:
#    DateID  StateID  ManufacturerID  Score Manufacturer  \
# 0       7       14              13     89       Salvus
# 1       7       27              13     86       Salvus
# 2       7       44              13     85       Salvus
# 3       7       42              13     73       Salvus
# 4       7       41              13     82       Salvus
# 5       7       39              13     89       Salvus
# 6       7        7              13     80       Salvus
# 7       7       14              13     90       Salvus
# 8       7       36              13     78       Salvus
# 9       7       17              13     81       Salvus
#
#                       Date State    zip  ProductID
# 0  2013-07-01 00:00:00.000    IL  62356       1688
# 1  2013-07-01 00:00:00.000    ND  58001       1688
# 2  2013-07-01 00:00:00.000    VA  20041       1688
# 3  2013-07-01 00:00:00.000    TX    188       1688
# 4  2013-07-01 00:00:00.000    TN  42223       1688
# ...

# %%
sentiment.shape
# Out:
# (21473, 9)

# %%
sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21473 entries, 0 to 21472
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DateID          21473 non-null  int64
#  1   StateID         21473 non-null  int64
#  2   ManufacturerID  21473 non-null  int64
#  3   Score           21473 non-null  int64
#  4   Manufacturer    21473 non-null  object
#  5   Date            21473 non-null  object
#  6   State           21473 non-null  object
#  7   zip             21473 non-null  int64
#  8   ProductID       21473 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 1.5+ MB

# %%
sentiment.describe()
# Out:
#              DateID       StateID  ManufacturerID         Score           zip  \
# count  21473.000000  21473.000000    21473.000000  21473.000000  21473.000000
# mean      15.504121     24.852885        7.489312     66.861547  24983.757742
# std        5.210598     14.209063        4.025532     18.861081  26727.837360
# min        7.000000      1.000000        1.000000     10.000000      1.000000
# 25%       11.000000     12.000000        4.000000     61.000000     72.000000
# 50%       16.000000     25.000000        7.000000     71.000000  19701.000000
# 75%       20.000000     37.000000       11.000000     81.000000  46001.000000
# max       24.000000     49.000000       14.000000     90.000000  88901.000000
#
#           ProductID
# count  21473.000000
# mean    1159.909887
# std      737.821915
# min        1.000000
# 25%      392.000000
# 50%     1043.000000
# 75%     1863.000000
# max     2187.000000

# %%
sentiment.columns
# Out:
# Index(['DateID', 'StateID', 'ManufacturerID', 'Score', 'Manufacturer', 'Date',
#        'State', 'zip', 'ProductID'],
#       dtype='object')

# %%
## average sentiment score

sentiment['Score'].mean()
# Out:
# 66.86154705909748

# %%
product.head(12)
# Out:
#    Manufacturer Category      Segment        Product  ProductID isVanArsdel  \
# 0     VanArsdel    Urban  Convenience  Maximus UC-01        536         Yes
# 1     VanArsdel    Urban  Convenience  Maximus UC-02        537         Yes
# 2     VanArsdel    Urban  Convenience  Maximus UC-03        538         Yes
# 3     VanArsdel    Urban  Convenience  Maximus UC-04        539         Yes
# 4     VanArsdel    Urban  Convenience  Maximus UC-05        540         Yes
# 5     VanArsdel    Urban  Convenience  Maximus UC-06        541         Yes
# 6     VanArsdel    Urban  Convenience  Maximus UC-07        542         Yes
# 7     VanArsdel    Urban  Convenience  Maximus UC-08        543         Yes
# 8     VanArsdel    Urban  Convenience  Maximus UC-09        544         Yes
# 9     VanArsdel    Urban  Convenience  Maximus UC-10        545         Yes
# 10    VanArsdel    Urban  Convenience  Maximus UC-11        546         Yes
# ...

# %%
# top 5 products

product['Product'].value_counts().head(5)
# Out:
# Quibus RP-29    3
# Quibus RP-26    3
# Quibus RP-34    3
# Quibus RP-33    3
# Quibus RP-32    3
# Name: Product, dtype: int64

# %%
product.shape
# Out:
# (2412, 9)

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2412 entries, 0 to 2411
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    2412 non-null   object
#  1   Category        2412 non-null   object
#  2   Segment         2412 non-null   object
#  3   Product         2412 non-null   object
#  4   ProductID       2412 non-null   int64
#  5   isVanArsdel     2412 non-null   object
#  6   IsCompeteHide   2412 non-null   object
#  7   ManufacturerID  2412 non-null   int64
#  8   IsCompete       2412 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 169.7+ KB

# %%
# check for null values
product.isnull().sum()
# Out:
# Manufacturer      0
# Category          0
# Segment           0
# Product           0
# ProductID         0
# isVanArsdel       0
# IsCompeteHide     0
# ManufacturerID    0
# IsCompete         0
# dtype: int64

# %%
product.describe()
# Out:
#          ProductID  ManufacturerID
# count  2412.000000     2412.000000
# mean   1206.500000        7.508292
# std     696.428747        3.867831
# min       1.000000        1.000000
# 25%     603.750000        4.000000
# 50%    1206.500000        8.000000
# 75%    1809.250000       11.000000
# max    2412.000000       14.000000

# %%
product['Manufacturer'].value_counts()
# Out:
# Quibus       455
# Natura       333
# VanArsdel    302
# Aliqui       226
# Abbas        198
# Currus       194
# Pirum        190
# Fama         181
# Pomum        137
# Victoria      85
# Leo           45
# Salvus        38
# Palma         16
# Barba         12
# Name: Manufacturer, dtype: int64

# %%
product['Manufacturer'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
product['Category'].value_counts()
# Out:
# Urban    1320
# Rural     743
# Mix       201
# Youth     148
# Name: Category, dtype: int64

# %%
product['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
product['Segment'].value_counts()
# Out:
# Productivity    598
# Convenience     405
# Extreme         347
# Moderation      306
# Regular         262
# Select          177
# All Season      169
# Youth           148
# Name: Segment, dtype: int64

# %%
product['Segment'].value_counts().plot(kind='pie', figsize = (20,8))
# Out:
# <Axes: ylabel='Segment'>

# %%
# all vanarsdel products
product.loc[product['isVanArsdel'] == 'Yes']
# Out:
#      Manufacturer Category       Segment        Product  ProductID  \
# 0       VanArsdel    Urban   Convenience  Maximus UC-01        536
# 1       VanArsdel    Urban   Convenience  Maximus UC-02        537
# 2       VanArsdel    Urban   Convenience  Maximus UC-03        538
# 3       VanArsdel    Urban   Convenience  Maximus UC-04        539
# 4       VanArsdel    Urban   Convenience  Maximus UC-05        540
# ...           ...      ...           ...            ...        ...
# 1152    VanArsdel    Urban       Regular  Maximus UR-01        512
# 1451    VanArsdel    Rural        Select  Maximus RS-01        394
# 1452    VanArsdel    Rural        Select  Maximus RS-02        395
# 1994    VanArsdel    Rural  Productivity  Maximus RP-01        392
# 1995    VanArsdel    Rural  Productivity  Maximus RP-02        393
#
#      isVanArsdel IsCompeteHide  ManufacturerID IsCompete
# 0            Yes             N               7        No
# ...

# %%
date.head(10)
# Out:
#                       Date  MonthNo MonthName  MonthID   Month Quarter  Year  \
# 0  1999-07-01 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 1  1999-07-02 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 2  1999-07-03 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 3  1999-07-04 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 4  1999-07-05 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 5  1999-07-06 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 6  1999-07-07 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 7  1999-07-08 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 8  1999-07-09 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
# 9  1999-07-10 00:00:00.000        7       Jul   199907  Jul-99      Q3  1999
#
#    RunningMonths  Running Year Running Months Rolling Period  \
# ...

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6209 entries, 0 to 6208
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 6209 non-null   object
#  1   MonthNo              6209 non-null   int64
#  2   MonthName            6209 non-null   object
#  3   MonthID              6209 non-null   int64
#  4   Month                6209 non-null   object
#  5   Quarter              6209 non-null   object
#  6   Year                 6209 non-null   int64
#  7   RunningMonths        6209 non-null   int64
#  8   Running Year         5844 non-null   float64
#  9   Running Months       1096 non-null   object
#  10  Rolling Period       1096 non-null   object
#  11  Rolling Period Sort  1096 non-null   float64
#  12  MonthIndex           6209 non-null   int64
#  13  Months               6209 non-null   object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 679.2+ KB

# %%
date.shape
# Out:
# (6209, 14)

# %%
date.describe()
# Out:
#            MonthNo        MonthID         Year  RunningMonths  Running Year  \
# count  6209.000000    6209.000000  6209.000000    6209.000000   5844.000000
# mean      6.523112  200706.458689  2006.999356      90.484619      8.500342
# std       3.448931     489.930407     4.899177      58.891794      4.610092
# min       1.000000  199901.000000  1999.000000     -11.000000      1.000000
# 25%       4.000000  200304.000000  2003.000000      39.000000      4.750000
# 50%       7.000000  200707.000000  2007.000000      90.000000      8.500000
# 75%      10.000000  201110.000000  2011.000000     141.000000     12.250000
# max      12.000000  201512.000000  2015.000000     192.000000     16.000000
#
#        Rolling Period Sort   MonthIndex
# count          1096.000000  6209.000000
# mean              6.521898   102.515381
# std               3.450561    58.891794
# min               1.000000     1.000000
# 25%               4.000000    52.000000
# ...

# %%
# check for null values
date.isnull().sum()
# Out:
# Date                      0
# MonthNo                   0
# MonthName                 0
# MonthID                   0
# Month                     0
# Quarter                   0
# Year                      0
# RunningMonths             0
# Running Year            365
# Running Months         5113
# Rolling Period         5113
# Rolling Period Sort    5113
# MonthIndex                0
# Months                    0
# dtype: int64

# %%
date.columns
# Out:
# Index(['Date', 'MonthNo', 'MonthName', 'MonthID', 'Month', 'Quarter', 'Year',
#        'RunningMonths', 'Running Year', 'Running Months', 'Rolling Period',
#        'Rolling Period Sort', 'MonthIndex', 'Months'],
#       dtype='object')

# %%
salesfact.head(10)
# Out:
#    ProductID                     Date    Zip  Units  Revenue
# 0       2213  2005-06-22 00:00:00.000  25526      1  1070.37
# 1       2213  2006-09-30 00:00:00.000  65279      1  1070.37
# 2       2213  2003-11-27 00:00:00.000  30028      1  1070.37
# 3       2213  2004-06-03 00:00:00.000  80120      1  1070.37
# 4       2213  2006-02-10 00:00:00.000  15135      1  1070.37
# 5       2213  2006-07-11 00:00:00.000  37179      1  1070.37
# 6       2213  2006-06-27 00:00:00.000  92103      1  1070.37
# 7       2213  2005-09-13 00:00:00.000  30733      1  1070.37
# 8       2213  2003-06-30 00:00:00.000  89801      1  1070.37
# 9       2213  2005-01-29 00:00:00.000  36545      1  1070.37

# %%
salesfact.tail(10)
# Out:
#          ProductID                     Date    Zip  Units    Revenue
# 1260742        764  2004-07-27 00:00:00.000  27522     40  146134.80
# 1260743        808  2009-05-26 00:00:00.000  77041     13   53636.31
# 1260744        715  2007-06-29 00:00:00.000  27707     12   23806.44
# 1260745        993  2005-10-26 00:00:00.000  75789     14   55557.18
# 1260746       1116  2011-02-27 00:00:00.000  30122     12   36280.44
# 1260747        981  2002-11-30 00:00:00.000  55903     19   35898.03
# 1260748       2090  2006-05-30 00:00:00.000  44460     26  111367.62
# 1260749        781  2006-09-10 00:00:00.000  90501     16   20351.52
# 1260750       1228  2006-01-29 00:00:00.000  78773     12   19648.44
# 1260751        769  2001-04-26 00:00:00.000  92503     18   56688.66

# %%
salesfact.shape
# Out:
# (1260752, 5)

# %%
salesfact['Revenue'].sum()
# Out:
# 7024409824.949998

# %%
# average product revenue

salesfact['Revenue'].mean()
# Out:
# 5571.784354185851

# %%
geo.head(12)
# Out:
#       Zip            City State Region      District
# 0   15201  Pittsburgh, PA    PA   East  District #13
# 1   15202  Pittsburgh, PA    PA   East  District #13
# 2   15203  Pittsburgh, PA    PA   East  District #13
# 3   15204  Pittsburgh, PA    PA   East  District #13
# 4   15205  Pittsburgh, PA    PA   East  District #13
# 5   15206  Pittsburgh, PA    PA   East  District #13
# 6   15207  Pittsburgh, PA    PA   East  District #13
# 7   15208  Pittsburgh, PA    PA   East  District #13
# 8   15209  Pittsburgh, PA    PA   East  District #13
# 9   15210  Pittsburgh, PA    PA   East  District #13
# 10  15211  Pittsburgh, PA    PA   East  District #13
# 11  15212  Pittsburgh, PA    PA   East  District #13

# %%
geo.shape
# Out:
# (39948, 5)

# %%
geo['District'].value_counts()
# Out:
# District #25    1597
# District #30    1518
# District #19    1513
# District #24    1511
# District #07    1492
# District #21    1459
# District #32    1459
# District #01    1337
# District #33    1326
# District #23    1210
# District #03    1148
# District #39    1113
# District #15    1095
# District #13    1083
# District #29    1059
# District #22    1056
# District #09    1044
# District #11    1033
# District #02    1010
# District #18     986
# District #34     983
# District #28     966
# District #16     963
# District #04     908
# District #35     850
# District #10     840
# District #17     837
# District #05     797
# District #37     796
# District #36     779
# District #27     771
# District #08     765
# District #06     749
# District #20     725
# District #12     691
# District #38     660
# District #26     644
# District #14     638
# District #31     537
# Name: District, dtype: int64
